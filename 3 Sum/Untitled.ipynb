# %%
class Solution:
    def threeSum(self, nums):
        length=len(nums)
        nums=sorted(nums)
        res=[]
        for idx,val in enumerate(nums):
            if idx>=length-2:
                break
            if idx>0 and val==nums[idx-1]:
                continue
            if val>0:
                break
            l=idx+1
            r=length-1
            while l<r:
                summ=val+nums[l]+nums[r]
                print(summ,l,r)
                if summ==0:
                    res.append((val,nums[l],nums[r]))
                    l+=1
                    r-=1
                if summ<0:
                    l+=1
                else:
                    l-=1
        return res

# %%
a=Solution()
a.threeSum([-1,0,1,2,-1,-4])
# Out:
# -3 1 5
# -3 2 5
# -2 3 5
# -1 4 5
# 0 2 5
# -1 2 4
# 0 3 4
# 3 4 5
# 2 3 5
# 1 2 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# -2 0 5
# 1 1 5
# ...

# %%
class Graph(object):
    def __init__(self):
        self.list={}
    def addEdge(self,s,v):
        '''if s in self.list:
            self.list[s].append(v)
        else:
            self.list[s]=[v]'''
        if v in self.list:
            self.list[v].append(s)
        else:
            self.list[v]=[s]
    def display(self):
        print(self.list)
            
class Solution:
    def minNumberOfSemesters(self, n, dependencies, k):
        g=Graph()
        #Make the graph
        for s,v in dependencies:
            g.addEdge(s,v)
        d={}
        #Do DFS in the graph and return level
        queue=[]
        queue.append(n)
        visited=set()
        self.pairs={}
        def dfs(node,level):
            if node:
                level+=1
                print(node,level)
                #altLevel=n-level
                if level in self.pairs:
                    self.pairs[level].append(node)
                else:
                    self.pairs[level]=[node]
                visited.add(node)
                if node in g.list:
                    for connectedNode in g.list[node]:
                        if connectedNode not in visited:
                            visited.add(connectedNode)
                            dfs(connectedNode,level)
        dfs(n,0)
        import math
        #print(self.pairs)
        for key in self.pairs:
            self.pairs[key]=len(self.pairs[key])
        print(self.pairs)
        level=n
        terms=0
        while level!=0:
            if level!=1:
                self.pairs[level-1]-=k
                if self.pairs[level-1]<=0:
                    terms+=1
                    level-=1
                else:
                    terms+=1
            else:
                terms+=math.ceil(self.pairs[1]/k)
                level-=1
        return terms

# %%
s=Solution()
s.minNumberOfSemesters(4,[[2,1],[3,1],[1,4]],2)
# Out:
# 4 1
# 1 2
# 2 3
# 3 3
# {1: 1, 2: 1, 3: 2}
# 3
